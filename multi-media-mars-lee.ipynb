# %%
# import IPython.display.Image class.
from IPython.display import Image

# create an Image object with specified url.
remote_image = Image(url='https://lh3.googleusercontent.com/proxy/s92MLZ-_4C9vFUVNUyn5JGi8LEQ5tkwFr0K-93tGyjW_rbC9ZLZEfhdMMtPWMi-4NriT3hzcICKnrfcStw71xy9kmxNaxGTVzyPMxyrErddw1_fQVJCdfTpgkkHq2FZX33V5f_DnSfIY4VuDOAg')
# display the remote image in jupyter notebook.
display(remote_image)
# Out:
# <img src="https://lh3.googleusercontent.com/proxy/s92MLZ-_4C9vFUVNUyn5JGi8LEQ5tkwFr0K-93tGyjW_rbC9ZLZEfhdMMtPWMi-4NriT3hzcICKnrfcStw71xy9kmxNaxGTVzyPMxyrErddw1_fQVJCdfTpgkkHq2FZX33V5f_DnSfIY4VuDOAg"/>

# %%
# import IPython.display.YouTubeVideo class.
from IPython.display import YouTubeVideo
# create an instance of YouTubeVideo class with provided youtube video id.
youtube_video = YouTubeVideo('WEH2fk0ONag')
# display youtube video
display(youtube_video)

#source: https://www.dev2qa.com/how-to-display-rich-output-media-audio-video-image-etc-in-ipython-jupyter-notebook/

# %%
# local image not displaying on github+nbviewer even though I added blingeepython.gif in directory
# import IPython.display.Image class.
from IPython.display import Image

# create an Image object with file path and name.
local_image = Image(filename='./blingeepython.gif')
# display the local image in jupyter notebook
local_image
# Out:
# <img src="https://i.imgur.com/KfQWW8d.gif"/>

# %%
# import IPython.display.Image class.
from IPython.display import Image

# create an Image object with specified url.
remote_image = Image(url='https://i.imgur.com/KfQWW8d.gif')
# display the remote image in jupyter notebook.
display(remote_image)
# Out:
# <img src="https://i.imgur.com/KfQWW8d.gif"/>

# %%
# import IPython.display.HTML class
from IPython.display import HTML
# create a string which contains html source code.
html_data = """In this page, you'll see how <span style="color:red">cool</span> I am! This is in HTML!""" # This is not displaying
# create a HTML object.
html = HTML(data=html_data)
# display the HTML object in jupyter notebook
html
# Out:
# In this page, you'll see how <span style="color:red">cool</span> I am!

# %% [markdown]
# I'm learning Jupyter notebook!! Don't be mean to teh newbies, lul! This is in markdown!
#
# Down below are my attemptz!

# %%
from IPython.core.magic import register_cell_magic

@register_cell_magic
def background(color, cell):
    set_background(color)
    return eval(cell)

# %%background honeydew
my_important_param = 42
# Out:
# UsageError: Line magic function `%%background` not found.

# %%
#playing with cell color

from IPython.display import HTML, display

def set_background(color):    
    script = (
        "var cell = this.closest('.jp-CodeCell');"
        "var editor = cell.querySelector('.jp-Editor');"
        "editor.style.background='{}';"
        "this.parentNode.removeChild(this)"
    ).format(color)
    
    display(HTML('<img src onerror="{}" style="display:none">'.format(script)))
    
set_background('honeydew')

# source: https://stackoverflow.com/questions/49429585/how-to-change-the-background-color-of-a-single-cell-in-a-jupyter-notebook-jupy
# Out:
# <img src onerror="var cell = this.closest('.jp-CodeCell');var editor = cell.querySelector('.jp-Editor');editor.style.background='honeydew';this.parentNode.removeChild(this)" style="display:none">

# %%
# code graveyard- in honor of those that tried but never made it xoxoxo

import IPython.core.display.DisplayObject

IPython.display.Video(https://www.youtube.com/watch?v=WEH2fk0ONag)

source: https://ipython.readthedocs.io/en/stable/api/generated/IPython.display.html#IPython.display.Audio

# %%HTML
<video width="320" height="240" controls>
  <source src="https://www.youtube.com/watch?v=WEH2fk0ONag">
</video>

from IPython.display import Video

Video('https://www.youtube.com/watch?v=WEH2fk0ONag')
# Out:
# <video width="320" height="240" controls>
#   <source src="https://www.youtube.com/watch?v=WEH2fk0ONag">
# </video>

# %%
# import IPython.display.Image class.
from IPython.display import Image

# create an Image object with specified url.
remote_image = Image(url='https://i.gifer.com/Osm4.gif')
# display the remote image in jupyter notebook.
display(remote_image)
# Out:
# <img src="https://i.gifer.com/Osm4.gif"/>
